# %%
# !pip install ultralytics --user
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.3.52-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\python310\lib\site-packages (from ultralytics) (3.9.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\python310\lib\site-packages (from ultralytics) (4.6.0.66)
# Requirement already satisfied: pillow>=7.1.2 in c:\python310\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\python310\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\python310\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\python310\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ultralytics) (2.4.1)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.20.1-cp310-cp310-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\python310\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: py-cpuinfo in c:\python310\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\python310\lib\site-packages (from ultralytics) (2.0.0)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\python310\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in c:\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.5.1-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\python310\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python310\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Using cached ultralytics-8.3.52-py3-none-any.whl (901 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached torchvision-0.20.1-cp310-cp310-win_amd64.whl (1.6 MB)
# Using cached torch-2.5.1-cp310-cp310-win_amd64.whl (203.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: sympy, torch, ultralytics-thop, torchvision, seaborn, ultralytics
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
# Successfully installed seaborn-0.13.2 sympy-1.13.1 torch-2.5.1 torchvision-0.20.1 ultralytics-8.3.52 ultralytics-thop-2.0.13
# [notice] A new release of pip is available: 24.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="./dataset", epochs=5, imgsz=640)
# Out:
# Ultralytics 8.3.52  Python-3.10.6 torch-2.5.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# engine\trainer: task=classify, mode=train, model=yolo11n-cls.pt, data=./dataset, epochs=5, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\classify\train2
# train: C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\train... found 500 images in 4 classes
# val: None...
# test: C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\test... found 22 images in 4 classes
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    335364  ultralytics.nn.modules.head.Classify         [256, 4]
# YOLO11n-cls summary: 151 layers, 1,536,228 parameters, 1,536,228 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\classify\train2', view at http://localhost:6006/
# train: Scanning C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\train... 500 images, 0 corrupt: 100%|██████████| 500/500 [00:01<00:00, 432.36it/s]
# train: New cache created: C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\train.cache
# val: Scanning C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\test... 22 images, 0 corrupt: 100%|██████████| 22/22 [00:00<00:00, 1270.63it/s]
# val: New cache created: C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\classify\train2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/5         0G      1.027          4        640: 100%|██████████| 32/32 [02:08<00:00,  4.02s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:01<00:00,  1.61s/it]
#                    all      0.682          1
#       Epoch    GPU_mem       loss  Instances       Size
#         2/5         0G     0.3832          4        640: 100%|██████████| 32/32 [02:08<00:00,  4.00s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
#                    all      0.727          1
#       Epoch    GPU_mem       loss  Instances       Size
#         3/5         0G     0.2038          4        640: 100%|██████████| 32/32 [02:07<00:00,  4.00s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
#                    all      0.818          1
#       Epoch    GPU_mem       loss  Instances       Size
#         4/5         0G     0.1416          4        640: 100%|██████████| 32/32 [01:59<00:00,  3.73s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
#                    all      0.909          1
#       Epoch    GPU_mem       loss  Instances       Size
#         5/5         0G    0.09894          4        640: 100%|██████████| 32/32 [02:00<00:00,  3.76s/it]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:01<00:00,  1.55s/it]
#                    all      0.955          1
# 5 epochs completed in 0.177 hours.
# Optimizer stripped from runs\classify\train2\weights\last.pt, 3.2MB
# Optimizer stripped from runs\classify\train2\weights\best.pt, 3.2MB
#
# Validating runs\classify\train2\weights\best.pt...
# Ultralytics 8.3.52  Python-3.10.6 torch-2.5.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# YOLO11n-cls summary (fused): 112 layers, 1,531,148 parameters, 0 gradients, 3.2 GFLOPs
# WARNING  Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\train... found 500 images in 4 classes
# val: None...
# test: C:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\test... found 22 images in 4 classes
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
#                    all      0.955          1
# Speed: 0.0ms preprocess, 35.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\train2
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\LENOVO\AppData\Roaming\Ultralytics\Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 3.68MB/s]

# %%
from IPython.display import Image

Image("./runs/classify/train2/results.png", width=600)

# %%
model = YOLO("./runs/classify/train2/weights/best.pt")

result = model("./dataset/test/Bus/blue-bus.jpg")
result[0].show()
# Out:
# image 1/1 c:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\test\Bus\blue-bus.jpg: 640x640 Bus 0.94, Truck 0.05, Car 0.01, Motorcycle 0.00, 54.7ms
# Speed: 19.4ms preprocess, 54.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
