# %%
# !pip install ultralytics --user
# Out:
# ...
# [notice] A new release of pip is available: 24.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="./dataset", epochs=10, imgsz=640)
# Out:
# Ultralytics 8.3.52  Python-3.10.6 torch-2.5.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# ...

# %%
from IPython.display import Image

Image("./runs/classify/train3/results.png", width=600)

# %%
model = YOLO("./cnn_model.pt")

result = model.predict("./dataset/test/Bus/blue-bus.jpg", conf=0.01)
print(result[0].probs.top1)
print(result[0].probs.top1conf.item())
# Out:
# image 1/1 c:\Users\LENOVO\Kuliah\Tingkat4\PCD\IF4073-Vehicle-Recognition\dataset\test\Bus\blue-bus.jpg: 640x640 Bus 0.96, Truck 0.03, Car 0.01, Motorcycle 0.00, 44.9ms
# Speed: 13.4ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0
# 0.9578734040260315
